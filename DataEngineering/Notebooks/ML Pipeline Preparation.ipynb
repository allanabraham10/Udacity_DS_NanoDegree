# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import numpy as np
import plotly
# from plotly import express as px
import time
import datetime
from sqlalchemy import create_engine

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words("english"))
nltk.download('omw-1.4')

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB

import matplotlib.pyplot as plt

import pickle
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
# load data from database
engine = create_engine('sqlite:///ETLPipelinePrep.db')
df = pd.read_sql_table('Disasters_ETL', engine)
X = df.message
y = df[df.columns[4:]]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text, remove_stopwords=True):
    
    # normalize case and remove punctuation
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    
    # tokenize text
    tokens = word_tokenize(text)
    
    # lower-case and lemmatize
    lemmatizer = WordNetLemmatizer()
    clean_tokens = []
    for t in tokens:
        clean_tok = lemmatizer.lemmatize(t).lower().strip()
        clean_tokens.append(clean_tok)
    
    # remove stopwords
    if remove_stopwords:
        clean_tokens = [word for word in clean_tokens if word not in stop_words]
        
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
Y_pred = pipeline.predict(X_test)

# %%
category_names = y.columns

for i in range(36):
    print(Y_test.columns[i], ':')
    print(classification_report(Y_test.iloc[:,i], Y_pred[:,i]))
# Out:
# related :
#              precision    recall  f1-score   support
#
#           0       0.62      0.45      0.52      1504
#           1       0.84      0.91      0.88      4994
#           2       0.53      0.16      0.25        56
#
# avg / total       0.79      0.80      0.79      6554
#
# request :
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93      5413
#           1       0.78      0.44      0.57      1141
#
# avg / total       0.87      0.88      0.87      6554
#
# offer :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_related :
#              precision    recall  f1-score   support
#
#           0       0.76      0.85      0.80      3855
#           1       0.74      0.62      0.68      2699
#
# avg / total       0.75      0.75      0.75      6554
#
# medical_help :
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6026
#           1       0.58      0.08      0.13       528
#
# avg / total       0.90      0.92      0.89      6554
#
# medical_products :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6229
#           1       0.67      0.10      0.18       325
#
# avg / total       0.94      0.95      0.94      6554
#
# search_and_rescue :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6373
#           1       0.36      0.03      0.05       181
#
# avg / total       0.96      0.97      0.96      6554
#
# security :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6435
#           1       0.25      0.01      0.02       119
#
# avg / total       0.97      0.98      0.97      6554
#
# military :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6339
#           1       0.65      0.10      0.18       215
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water :
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6111
#           1       0.86      0.44      0.58       443
#
# avg / total       0.95      0.96      0.95      6554
#
# food :
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5833
#           1       0.84      0.49      0.62       721
#
# avg / total       0.93      0.93      0.93      6554
#
# shelter :
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5966
#           1       0.81      0.35      0.49       588
#
# avg / total       0.93      0.93      0.92      6554
#
# clothing :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6455
#           1       0.54      0.13      0.21        99
#
# avg / total       0.98      0.99      0.98      6554
#
# money :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6419
#           1       0.50      0.01      0.03       135
#
# avg / total       0.97      0.98      0.97      6554
#
# missing_people :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.33      0.01      0.03        75
#
# avg / total       0.98      0.99      0.98      6554
#
# refugees :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6322
#           1       0.54      0.03      0.06       232
#
# avg / total       0.95      0.96      0.95      6554
#
# death :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6246
#           1       0.75      0.16      0.26       308
#
# avg / total       0.95      0.96      0.94      6554
#
# other_aid :
#              precision    recall  f1-score   support
#
#           0       0.87      0.99      0.93      5650
#           1       0.53      0.05      0.09       904
#
# avg / total       0.82      0.86      0.81      6554
#
# infrastructure_related :
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6169
#           1       0.21      0.01      0.02       385
#
# avg / total       0.90      0.94      0.91      6554
#
# transport :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6252
#           1       0.62      0.11      0.19       302
#
# avg / total       0.94      0.96      0.94      6554
#
# buildings :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6208
#           1       0.82      0.12      0.21       346
#
# avg / total       0.95      0.95      0.94      6554
#
# electricity :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.43      0.02      0.04       132
#
# avg / total       0.97      0.98      0.97      6554
#
# tools :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6511
#           1       0.00      0.00      0.00        43
#
# avg / total       0.99      0.99      0.99      6554
#
# hospitals :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6497
#           1       0.00      0.00      0.00        57
#
# avg / total       0.98      0.99      0.99      6554
#
# shops :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6533
#           1       0.00      0.00      0.00        21
#
# avg / total       0.99      1.00      1.00      6554
#
# aid_centers :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6482
#           1       0.00      0.00      0.00        72
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6282
#           1       0.30      0.01      0.02       272
#
# avg / total       0.93      0.96      0.94      6554
#
# weather_related :
#              precision    recall  f1-score   support
#
#           0       0.87      0.95      0.91      4704
#           1       0.83      0.63      0.72      1850
#
# avg / total       0.86      0.86      0.85      6554
#
# floods :
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      6009
#           1       0.83      0.24      0.37       545
#
# avg / total       0.93      0.93      0.91      6554
#
# storm :
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5911
#           1       0.78      0.41      0.54       643
#
# avg / total       0.92      0.93      0.92      6554
#
# fire :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6483
#           1       0.50      0.01      0.03        71
#
# avg / total       0.98      0.99      0.98      6554
#
# earthquake :
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      5925
#           1       0.87      0.70      0.78       629
#
# avg / total       0.96      0.96      0.96      6554
#
# cold :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6431
#           1       0.73      0.07      0.12       123
#
# avg / total       0.98      0.98      0.97      6554
#
# other_weather :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6222
#           1       0.50      0.05      0.09       332
#
# avg / total       0.93      0.95      0.93      6554
#
# direct_report :
#              precision    recall  f1-score   support
#
#           0       0.85      0.97      0.91      5274
#           1       0.71      0.31      0.43      1280
#
# avg / total       0.82      0.84      0.81      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
nltk.download('stopwords', quiet=True, raise_on_error=True)
stop_words = set(nltk.corpus.stopwords.words('english'))
tokenized_stop_words = nltk.word_tokenize(' '.join(nltk.corpus.stopwords.words('english')))
tokenized_stop_words[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you']

# %%
parameters = {
    'vect__stop_words': (tokenized_stop_words, None),
    'vect__ngram_range': ((1, 1), (1, 2)),
    'vect__max_df': (0.5, 0.75, 1.0)
    }

cv = GridSearchCV(pipeline, param_grid=parameters, verbose=3)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train, Y_train)
Y_pred = cv.predict(X_test)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23558132438205676, total=  42.5s
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   51.1s remaining:    0.0s
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2364967958498627, total=  42.4s
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.7min remaining:    0.0s
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23558132438205676, total=  43.0s
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.23436069575831553, total=  43.0s
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.232834909978639, total=  42.9s
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.2380225816295392, total=  42.7s
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23924321025328044, total= 1.5min
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.24671956057369546, total= 1.5min
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23298748855660664, total= 1.5min
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.2456515105279219, total= 1.5min
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.23680195300579798, total= 1.5min
# [CV] vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=0.5, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.2400061031431187, total= 1.5min
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2354287458040891, total=  44.4s
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23848031736344216, total=  44.3s
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23634421727189503, total=  44.3s
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.2351235886481538, total=  43.7s
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.24610924626182484, total=  43.6s
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.23924321025328044, total=  43.8s
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2364967958498627, total= 1.6min
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2465669819957278, total= 1.5min
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.24107415318889228, total= 1.6min
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.2462618248397925, total= 1.6min
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.240311260299054, total= 1.5min
# [CV] vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=0.75, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.23481843149221848, total= 1.4min
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23146170277693012, total=  43.9s
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2397009459871834, total=  43.7s
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2354287458040891, total=  43.9s
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.24046383887702166, total=  43.1s
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.23695453158376564, total=  43.2s
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=None
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 1), vect__stop_words=None, score=0.2397009459871834, total=  43.6s
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.23634421727189503, total= 1.5min
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.2380225816295392, total= 1.5min
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"]
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'you', "'re", 'you', "'ve", 'you', "'ll", 'you', "'d", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'she', "'s", 'her', 'hers', 'herself', 'it', 'it', "'s", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'that', "'ll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'do', "n't", 'should', 'should', "'ve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'are', "n't", 'couldn', 'could', "n't", 'didn', 'did', "n't", 'doesn', 'does', "n't", 'hadn', 'had', "n't", 'hasn', 'has', "n't", 'haven', 'have', "n't", 'isn', 'is', "n't", 'ma', 'mightn', 'might', "n't", 'mustn', 'must', "n't", 'needn', 'need', "n't", 'shan', 'sha', "n't", 'shouldn', 'should', "n't", 'wasn', 'was', "n't", 'weren', 'were', "n't", 'won', 'wo', "n't", 'wouldn', 'would', "n't"], score=0.24046383887702166, total= 1.5min
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.2436679890143424, total= 1.5min
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.24977113213304852, total= 1.5min
# [CV] vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=None
# [CV]  vect__max_df=1.0, vect__ngram_range=(1, 2), vect__stop_words=None, score=0.2351235886481538, total= 1.5min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 46.3min finished

# %%
print(cv.best_params_, cv.best_score_)
# Out:
# {'vect__max_df': 1.0, 'vect__ngram_range': (1, 2), 'vect__stop_words': None} 0.242854236599

# %%
category_names = y.columns

for i in range(36):
    print(Y_test.columns[i], ':')
    print(classification_report(Y_test.iloc[:,i], Y_pred[:,i]))
# Out:
# related :
#              precision    recall  f1-score   support
#
#           0       0.57      0.50      0.53      1504
#           1       0.85      0.88      0.87      4994
#           2       0.30      0.23      0.26        56
#
# avg / total       0.78      0.79      0.78      6554
#
# request :
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93      5413
#           1       0.76      0.45      0.57      1141
#
# avg / total       0.87      0.88      0.87      6554
#
# offer :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_related :
#              precision    recall  f1-score   support
#
#           0       0.74      0.87      0.80      3855
#           1       0.75      0.57      0.65      2699
#
# avg / total       0.75      0.75      0.74      6554
#
# medical_help :
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6026
#           1       0.63      0.06      0.12       528
#
# avg / total       0.90      0.92      0.89      6554
#
# medical_products :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6229
#           1       0.65      0.10      0.17       325
#
# avg / total       0.94      0.95      0.94      6554
#
# search_and_rescue :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6373
#           1       0.81      0.07      0.13       181
#
# avg / total       0.97      0.97      0.96      6554
#
# security :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6435
#           1       0.33      0.01      0.02       119
#
# avg / total       0.97      0.98      0.97      6554
#
# military :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6339
#           1       0.65      0.07      0.13       215
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6111
#           1       0.89      0.39      0.54       443
#
# avg / total       0.95      0.96      0.95      6554
#
# food :
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.97      5833
#           1       0.82      0.58      0.68       721
#
# avg / total       0.94      0.94      0.94      6554
#
# shelter :
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5966
#           1       0.82      0.22      0.35       588
#
# avg / total       0.92      0.93      0.91      6554
#
# clothing :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6455
#           1       0.57      0.08      0.14        99
#
# avg / total       0.98      0.99      0.98      6554
#
# money :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6419
#           1       0.80      0.06      0.11       135
#
# avg / total       0.98      0.98      0.97      6554
#
# missing_people :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.50      0.01      0.03        75
#
# avg / total       0.98      0.99      0.98      6554
#
# refugees :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6322
#           1       0.60      0.03      0.05       232
#
# avg / total       0.95      0.96      0.95      6554
#
# death :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6246
#           1       0.74      0.16      0.27       308
#
# avg / total       0.95      0.96      0.94      6554
#
# other_aid :
#              precision    recall  f1-score   support
#
#           0       0.87      0.99      0.93      5650
#           1       0.50      0.05      0.10       904
#
# avg / total       0.82      0.86      0.81      6554
#
# infrastructure_related :
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6169
#           1       0.18      0.01      0.02       385
#
# avg / total       0.90      0.94      0.91      6554
#
# transport :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6252
#           1       0.62      0.05      0.09       302
#
# avg / total       0.94      0.95      0.94      6554
#
# buildings :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6208
#           1       0.82      0.16      0.27       346
#
# avg / total       0.95      0.95      0.94      6554
#
# electricity :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       1.00      0.02      0.04       132
#
# avg / total       0.98      0.98      0.97      6554
#
# tools :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6511
#           1       0.00      0.00      0.00        43
#
# avg / total       0.99      0.99      0.99      6554
#
# hospitals :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6497
#           1       0.00      0.00      0.00        57
#
# avg / total       0.98      0.99      0.99      6554
#
# shops :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6533
#           1       0.00      0.00      0.00        21
#
# avg / total       0.99      1.00      1.00      6554
#
# aid_centers :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6482
#           1       0.00      0.00      0.00        72
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6282
#           1       0.27      0.01      0.02       272
#
# avg / total       0.93      0.96      0.94      6554
#
# weather_related :
#              precision    recall  f1-score   support
#
#           0       0.83      0.96      0.89      4704
#           1       0.84      0.51      0.63      1850
#
# avg / total       0.83      0.83      0.82      6554
#
# floods :
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6009
#           1       0.87      0.33      0.48       545
#
# avg / total       0.94      0.94      0.93      6554
#
# storm :
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5911
#           1       0.78      0.35      0.48       643
#
# avg / total       0.92      0.93      0.91      6554
#
# fire :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6483
#           1       1.00      0.03      0.05        71
#
# avg / total       0.99      0.99      0.98      6554
#
# earthquake :
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      5925
#           1       0.85      0.61      0.71       629
#
# avg / total       0.95      0.95      0.95      6554
#
# cold :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6431
#           1       0.70      0.11      0.20       123
#
# avg / total       0.98      0.98      0.98      6554
#
# other_weather :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6222
#           1       0.33      0.02      0.03       332
#
# avg / total       0.92      0.95      0.93      6554
#
# direct_report :
#              precision    recall  f1-score   support
#
#           0       0.86      0.97      0.91      5274
#           1       0.70      0.33      0.44      1280
#
# avg / total       0.83      0.84      0.82      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize, max_df=0.5, ngram_range=(1, 2), stop_words=tokenized_stop_words)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier(random_state = 42)))
    ])

# %%
from sklearn.linear_model import SGDClassifier
parameters = {
    'clf': (MultiOutputClassifier(SGDClassifier(random_state = 42)),
            MultiOutputClassifier(RandomForestClassifier(random_state = 42)))
}

# %%
cv = GridSearchCV(pipeline, param_grid=parameters, verbose=3)
df_nochildalone = df.drop(['child_alone'], axis=1)

X_nochildalone = df_nochildalone['message']
Y_nochildalone = df_nochildalone.iloc[:, 4:]
X_train_nca, X_test_nca, Y_train_nca, Y_test_nca = train_test_split(X_nochildalone, Y_nochildalone, test_size=0.2, random_state=42, shuffle=True)

# %%
# Train classifier
cv.fit(X_train_nca, Y_train_nca)
Y_pred = cv.predict(X_test_nca)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV] clf=MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
# [CV]  clf=MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1), score=0.2590473465884709, total=  10.2s
# [CV] clf=MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.2s remaining:    0.0s
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
# [CV]  clf=MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1), score=0.27077671291660704, total=  10.2s
# [CV] clf=MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   32.3s remaining:    0.0s
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
# [CV]  clf=MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1), score=0.2738197424892704, total=  10.2s
# [CV] clf=MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#            n_jobs=1)
# [CV]  clf=MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#            n_jobs=1), score=0.2351594907738521, total= 1.5min
# [CV] clf=MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
# ...
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#            n_jobs=1), score=0.23329995708768417, total= 1.5min
# [CV] clf=MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#            n_jobs=1)
# [CV]  clf=MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#            n_jobs=1), score=0.23834048640915595, total= 1.6min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  6.0min finished
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning:
#
# max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.

# %%
print(cv.best_params_, cv.best_score_)
# Out:
# {'clf': MultiOutputClassifier(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#            n_jobs=1)} 0.267880984169

# %%
for i in range(len(y.columns)):
    print(Y_test.columns[i], ':')
    try:
        print(classification_report(Y_test_nca.iloc[:,i], Y_pred[:,i]))
    except:
        print()
# Out:
# related :
#              precision    recall  f1-score   support
#
#           0       0.73      0.35      0.47      1266
#           1       0.81      0.96      0.88      3938
#           2       0.00      0.00      0.00        40
#
# avg / total       0.79      0.80      0.78      5244
#
# request :
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.94      4349
#           1       0.80      0.56      0.66       895
#
# avg / total       0.90      0.90      0.89      5244
#
# offer :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      5218
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      1.00      0.99      5244
#
# aid_related :
#              precision    recall  f1-score   support
#
#           0       0.81      0.82      0.81      3113
#           1       0.73      0.73      0.73      2131
#
# avg / total       0.78      0.78      0.78      5244
#
# medical_help :
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      4822
#           1       0.68      0.13      0.22       422
#
# avg / total       0.91      0.92      0.90      5244
#
# medical_products :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      4974
#           1       0.77      0.19      0.30       270
#
# avg / total       0.95      0.96      0.94      5244
#
# search_and_rescue :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      5117
#           1       1.00      0.06      0.10       127
#
# avg / total       0.98      0.98      0.97      5244
#
# security :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      5156
#           1       0.00      0.00      0.00        88
#
# avg / total       0.97      0.98      0.97      5244
#
# military :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5089
#           1       0.45      0.03      0.06       155
#
# avg / total       0.96      0.97      0.96      5244
#
# child_alone :
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      4905
#           1       0.75      0.62      0.68       339
#
# avg / total       0.96      0.96      0.96      5244
#
# water :
#              precision    recall  f1-score   support
#
#           0       0.97      0.98      0.97      4649
#           1       0.83      0.76      0.79       595
#
# avg / total       0.95      0.95      0.95      5244
#
# food :
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      4774
#           1       0.82      0.52      0.63       470
#
# avg / total       0.94      0.95      0.94      5244
#
# shelter :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      5171
#           1       0.81      0.34      0.48        73
#
# avg / total       0.99      0.99      0.99      5244
#
# clothing :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      5140
#           1       0.50      0.02      0.04       104
#
# avg / total       0.97      0.98      0.97      5244
#
# money :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      5184
#           1       0.00      0.00      0.00        60
#
# avg / total       0.98      0.99      0.98      5244
#
# missing_people :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5073
#           1       0.73      0.06      0.12       171
#
# avg / total       0.96      0.97      0.96      5244
#
# refugees :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5007
#           1       0.89      0.35      0.50       237
#
# avg / total       0.97      0.97      0.96      5244
#
# death :
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      4549
#           1       0.55      0.02      0.03       695
#
# avg / total       0.83      0.87      0.81      5244
#
# other_aid :
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      4916
#           1       0.00      0.00      0.00       328
#
# avg / total       0.88      0.94      0.91      5244
#
# infrastructure_related :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      5004
#           1       0.73      0.07      0.12       240
#
# avg / total       0.95      0.96      0.94      5244
#
# transport :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      4977
#           1       0.88      0.19      0.31       267
#
# avg / total       0.95      0.96      0.94      5244
#
# buildings :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      5122
#           1       0.80      0.03      0.06       122
#
# avg / total       0.97      0.98      0.97      5244
#
# electricity :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      5212
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      5244
#
# tools :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      5198
#           1       0.00      0.00      0.00        46
#
# avg / total       0.98      0.99      0.99      5244
#
# hospitals :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      5222
#           1       0.00      0.00      0.00        22
#
# avg / total       0.99      1.00      0.99      5244
#
# shops :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      5177
#           1       0.00      0.00      0.00        67
#
# avg / total       0.97      0.99      0.98      5244
#
# aid_centers :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      5021
#           1       0.00      0.00      0.00       223
#
# avg / total       0.92      0.96      0.94      5244
#
# other_infrastructure :
#              precision    recall  f1-score   support
#
#           0       0.90      0.95      0.92      3806
#           1       0.84      0.71      0.77      1438
#
# avg / total       0.88      0.88      0.88      5244
#
# weather_related :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      4833
#           1       0.91      0.52      0.66       411
#
# avg / total       0.96      0.96      0.95      5244
#
# floods :
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      4758
#           1       0.71      0.59      0.65       486
#
# avg / total       0.94      0.94      0.94      5244
#
# storm :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      5191
#           1       0.50      0.04      0.07        53
#
# avg / total       0.99      0.99      0.99      5244
#
# fire :
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      4766
#           1       0.88      0.80      0.84       478
#
# avg / total       0.97      0.97      0.97      5244
#
# earthquake :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      5127
#           1       0.75      0.10      0.18       117
#
# avg / total       0.97      0.98      0.97      5244
#
# cold :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      4968
#           1       0.67      0.01      0.01       276
#
# avg / total       0.93      0.95      0.92      5244
#
# other_weather :
#              precision    recall  f1-score   support
#
#           0       0.87      0.97      0.92      4223
#           1       0.75      0.41      0.53      1021
#
# avg / total       0.85      0.86      0.84      5244
#
# direct_report :
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.

# %%
#specifying the best parameters that were determined in the previous gridsearch step
pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize, max_df=0.5, ngram_range=(1, 2), stop_words='english')),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(SGDClassifier(random_state = 42)))
    ])

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import gzip
with gzip.open('model.p.gz', 'wb') as gzipped_f:
    # Pickle the trained pipeline using the highest protocol available.
    pickled = pickle.dumps(pipeline)
    gzipped_f.write(pickled)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
